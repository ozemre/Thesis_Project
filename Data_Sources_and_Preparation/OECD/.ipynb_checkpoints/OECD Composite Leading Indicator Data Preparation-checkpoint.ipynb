# %%
import numpy as np
import pandas as pd

# %%
df0 = pd.read_csv('OECD_Data\CLI_Indices.csv')

# %%
df0
# Out:
#        SUBJECT                                            Subject LOCATION  \
# 0     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 1     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 2     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 3     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 4     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 5     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 6     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 7     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 8     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 9     BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 10    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 11    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 12    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 13    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 14    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 15    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 16    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 17    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 18    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 19    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 20    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 21    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 22    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 23    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 24    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 25    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 26    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 27    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 28    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# 29    BSCICP03  OECD Standardised BCI, Amplitude adjusted (Lon...      TUR
# ...        ...                                                ...      ...
# 2582  LORSGPNO                                   Normalised (GDP)      CHN
# 2583  LORSGPNO                                   Normalised (GDP)      CHN
# 2584  LORSGPNO                                   Normalised (GDP)      CHN
# 2585  LORSGPNO                                   Normalised (GDP)      CHN
# 2586  LORSGPNO                                   Normalised (GDP)      CHN
# 2587  LORSGPNO                                   Normalised (GDP)      CHN
# 2588  LORSGPNO                                   Normalised (GDP)      CHN
# 2589  LORSGPNO                                   Normalised (GDP)      CHN
# 2590  LORSGPNO                                   Normalised (GDP)      CHN
# 2591  LORSGPNO                                   Normalised (GDP)      CHN
# 2592  LORSGPNO                                   Normalised (GDP)      CHN
# 2593  LORSGPNO                                   Normalised (GDP)      CHN
# 2594  LORSGPNO                                   Normalised (GDP)      CHN
# 2595  LORSGPNO                                   Normalised (GDP)      CHN
# 2596  LORSGPNO                                   Normalised (GDP)      CHN
# 2597  LORSGPNO                                   Normalised (GDP)      CHN
# 2598  LORSGPNO                                   Normalised (GDP)      CHN
# 2599  LORSGPNO                                   Normalised (GDP)      CHN
# 2600  LORSGPNO                                   Normalised (GDP)      CHN
# 2601  LORSGPNO                                   Normalised (GDP)      CHN
# 2602  LORSGPNO                                   Normalised (GDP)      CHN
# 2603  LORSGPNO                                   Normalised (GDP)      CHN
# 2604  LORSGPNO                                   Normalised (GDP)      CHN
# 2605  LORSGPNO                                   Normalised (GDP)      CHN
# 2606  LORSGPNO                                   Normalised (GDP)      CHN
# 2607  LORSGPNO                                   Normalised (GDP)      CHN
# 2608  LORSGPNO                                   Normalised (GDP)      CHN
# 2609  LORSGPNO                                   Normalised (GDP)      CHN
# 2610  LORSGPNO                                   Normalised (GDP)      CHN
# 2611  LORSGPNO                                   Normalised (GDP)      CHN
#
#                            Country FREQUENCY Frequency     TIME      Time  \
# 0                           Turkey         M   Monthly  2000-01  Jan-2000
# 1                           Turkey         M   Monthly  2000-02  Feb-2000
# 2                           Turkey         M   Monthly  2000-03  Mar-2000
# 3                           Turkey         M   Monthly  2000-04  Apr-2000
# 4                           Turkey         M   Monthly  2000-05  May-2000
# 5                           Turkey         M   Monthly  2000-06  Jun-2000
# 6                           Turkey         M   Monthly  2000-07  Jul-2000
# 7                           Turkey         M   Monthly  2000-08  Aug-2000
# 8                           Turkey         M   Monthly  2000-09  Sep-2000
# 9                           Turkey         M   Monthly  2000-10  Oct-2000
# 10                          Turkey         M   Monthly  2000-11  Nov-2000
# 11                          Turkey         M   Monthly  2000-12  Dec-2000
# 12                          Turkey         M   Monthly  2001-01  Jan-2001
unit  PowerCode Code PowerCode  Reference Period Code  \
# 0          IDX  Index               0     Units                    NaN
# 1          IDX  Index               0     Units                    NaN
# 2          IDX  Index               0     Units                    NaN
# 3          IDX  Index               0     Units                    NaN
# 4          IDX  Index               0     Units                    NaN
# 5          IDX  Index               0     Units                    NaN
# 6          IDX  Index               0     Units                    NaN
# 7          IDX  Index               0     Units                    NaN
# 8          IDX  Index               0     Units                    NaN
# 9          IDX  Index               0     Units                    NaN
# 10         IDX  Index               0     Units                    NaN
# 11         IDX  Index               0     Units                    NaN
# 12         IDX  Index               0     Units                    NaN
# 13         IDX  Index               0     Units                    NaN
# 14         IDX  Index               0     Units                    NaN
# 15         IDX  Index               0     Units                    NaN
# 16         IDX  Index               0     Units                    NaN
# 17         IDX  Index               0     Units                    NaN
# 18         IDX  Index               0     Units                    NaN
# 19         IDX  Index               0     Units                    NaN
# 20         IDX  Index               0     Units                    NaN
# 21         IDX  Index               0     Units                    NaN
# 22         IDX  Index               0     Units                    NaN
# 23         IDX  Index               0     Units                    NaN
# 24         IDX  Index               0     Units                    NaN
# 25         IDX  Index               0     Units                    NaN
# 26         IDX  Index               0     Units                    NaN
# 27         IDX  Index               0     Units                    NaN
# 28         IDX  Index               0     Units                    NaN
# 29         IDX  Index               0     Units                    NaN
# ...        ...    ...             ...       ...                    ...
# 2582       IDX  Index               0     Units                    NaN
# 2583       IDX  Index               0     Units                    NaN
# 2584       IDX  Index               0     Units                    NaN
# 2585       IDX  Index               0     Units                    NaN
# 2586       IDX  Index               0     Units                    NaN
# 2587       IDX  Index               0     Units                    NaN
# 2588       IDX  Index               0     Units                    NaN
# 2589       IDX  Index               0     Units                    NaN
# 2590       IDX  Index               0     Units                    NaN
# 2591       IDX  Index               0     Units                    NaN
# 2592       IDX  Index               0     Units                    NaN
# 2593       IDX  Index               0     Units                    NaN
# 2594       IDX  Index               0     Units                    NaN
# 2595       IDX  Index               0     Units                    NaN
# 2596       IDX  Index               0     Units                    NaN
# 2597       IDX  Index               0     Units                    NaN
# 2598       IDX  Index               0     Units                    NaN
# 2599       IDX  Index               0     Units                    NaN
# 2600       IDX  Index               0     Units                    NaN
# 2601       IDX  Index               0     Units                    NaN
# 2602       IDX  Index               0     Units                    NaN
# 2603       IDX  Index               0     Units                    NaN
# 2604       IDX  Index               0     Units                    NaN
# 2605       IDX  Index               0     Units                    NaN
# 2606       IDX  Index               0     Units                    NaN
# 2607       IDX  Index               0     Units                    NaN
# 2608       IDX  Index               0     Units                    NaN
# 2609       IDX  Index               0     Units                    NaN
# 2610       IDX  Index               0     Units                    NaN
# 2611       IDX  Index               0     Units                    NaN
#
#       Reference Period      Value  Flag Codes  Flags
# 0                  NaN  101.35140         NaN    NaN
# 1                  NaN  101.50920         NaN    NaN
# 2                  NaN  101.66400         NaN    NaN
# 3                  NaN  101.46960         NaN    NaN
# 4                  NaN  101.47580         NaN    NaN
# 5                  NaN  101.71940         NaN    NaN
# 6                  NaN  101.69730         NaN    NaN
# 7                  NaN  100.87030         NaN    NaN
# 8                  NaN   98.88383         NaN    NaN
# 9                  NaN   96.71148         NaN    NaN
# 10                 NaN   95.17643         NaN    NaN
# 11                 NaN   94.83391         NaN    NaN
# 12                 NaN   95.08168         NaN    NaN
# 13                 NaN   94.88400         NaN    NaN
# 14                 NaN   97.12168         NaN    NaN
# 15                 NaN  102.01510         NaN    NaN
# 16                 NaN  105.47290         NaN    NaN
# 17                 NaN  106.09710         NaN    NaN
# 18                 NaN  105.16930         NaN    NaN
# 19                 NaN  102.33420         NaN    NaN
# 20                 NaN   99.07333         NaN    NaN
# 21                 NaN   98.78123         NaN    NaN
# 22                 NaN   99.96432         NaN    NaN
# 23                 NaN   99.54453         NaN    NaN
# 24                 NaN   98.12734         NaN    NaN
# 25                 NaN   98.91457         NaN    NaN
# 26                 NaN  100.67110         NaN    NaN
# 27                 NaN  101.07400         NaN    NaN
# 28                 NaN   99.97797         NaN    NaN
# 29                 NaN   99.48946         NaN    NaN
# ...                ...        ...         ...    ...
# 2582               NaN   99.58629         NaN    NaN
# 2583               NaN   99.55247         NaN    NaN
# 2584               NaN   99.52179         NaN    NaN
# 2585               NaN   99.49417         NaN    NaN
# 2586               NaN   99.47020         NaN    NaN
# 2587               NaN   99.45055         NaN    NaN
# 2588               NaN   99.43568         NaN    NaN
# 2589               NaN   99.42588         NaN    NaN
# 2590               NaN   99.42136         NaN    NaN
# 2591               NaN   99.42267         NaN    NaN
# 2592               NaN   99.43015         NaN    NaN
# 2593               NaN   99.44363         NaN    NaN
# 2594               NaN   99.46256         NaN    NaN
# 2595               NaN   99.48547         NaN    NaN
# 2596               NaN   99.51025         NaN    NaN
# 2597               NaN   99.53429         NaN    NaN
# 2598               NaN   99.55606         NaN    NaN
# 2599               NaN   99.57441         NaN    NaN
# 2600               NaN   99.58810         NaN    NaN
# 2601               NaN   99.59769         NaN    NaN
# 2602               NaN   99.60425         NaN    NaN
# 2603               NaN   99.60866         NaN    NaN
# 2604               NaN   99.61189         NaN    NaN
# 2605               NaN   99.61488         NaN    NaN
# 2606               NaN   99.61810         NaN    NaN
# 2607               NaN   99.62159         NaN    NaN
# 2608               NaN   99.62549         NaN    NaN
# 2609               NaN   99.63051         NaN    NaN
# 2610               NaN   99.63664         NaN    NaN
# 2611               NaN   99.64388         NaN    NaN
#
# [2612 rows x 17 columns]

# %%
def finddate(expression):
        
    year=expression.split('-')[0]
    month=expression.split('-')[1]
    date=int(year+month)

    return date

# %%
df0['Subject'].unique()
# Out:
# array(['OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
#        'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
#        'Normalised (CLI)', 'Normalised (GDP)'], dtype=object)

# %%
df0['SUBJECT'].unique()
# Out:
# array(['BSCICP03', 'CSCICP03', 'LOLITONO', 'LORSGPNO'], dtype=object)

# %%
df0['Country'].unique()
# Out:
# array(['Turkey', 'United Kingdom', "China (People's Republic of)"],
#       dtype=object)

# %%
df0['Unit'].unique()
# Out:
# array(['Index'], dtype=object)

# %%
df0['Subject'][df0['LOCATION']=='TUR'].unique()
# Out:
# array(['OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
#        'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
#        'Normalised (CLI)', 'Normalised (GDP)'], dtype=object)

# %%
df0['Subject'][df0['LOCATION']=='CHN'].unique()
#df0[df0['LOCATION']=='CHN']
# Out:
# array(['OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
#        'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
#        'Normalised (CLI)', 'Normalised (GDP)'], dtype=object)

# %%
df0['Subject'][df0['LOCATION']=='GBR'].unique()
# Out:
# array(['OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
#        'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
#        'Normalised (CLI)', 'Normalised (GDP)'], dtype=object)

# %%
#Selected Indices  
#'OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
#'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
#'Normalised (CLI)', 
#'Normalised (GDP)'


# BCI 'BSCICP03'=>'OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
# CCI 'CSCICP03'=>'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
# CLI 'LOLITONO'=>'Normalised (CLI)'
# GDP 'LORSGPNO'=>'Normalised (GDP)'

# %%
#df0['SUBJECT'][(df0['Subject']=='OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa')].unique()
#df0['SUBJECT'][(df0['Subject']=='OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa')].unique()
#df0['SUBJECT'][(df0['Subject']=='Normalised (CLI)')].unique()
df0['SUBJECT'][(df0['Subject']=='Normalised (GDP)')].unique()
# Out:
# array(['LORSGPNO'], dtype=object)

# %%
#df0.count()

# %%
df=df0

# %%
df.drop('Subject',axis=1,inplace=True)
df.drop('Country',axis=1,inplace=True)
df.drop('Unit',axis=1,inplace=True)
df.drop('Unit Code',axis=1,inplace=True)
df.drop('PowerCode Code',axis=1,inplace=True)
df.drop('PowerCode',axis=1,inplace=True)
df.drop('Reference Period Code',axis=1,inplace=True)
df.drop('FREQUENCY',axis=1,inplace=True)
df.drop('Frequency',axis=1,inplace=True)
df.drop('Reference Period',axis=1,inplace=True)
df.drop('Flag Codes',axis=1,inplace=True)
df.drop('Time',axis=1,inplace=True)
df.drop('Flags',axis=1,inplace=True)

# %%
Turkey_BCI=df[(
    (df['LOCATION']=='TUR')   
   &(df['SUBJECT']=='BSCICP03') 
    )]
Turkey_BCI=Turkey_BCI.rename(columns = {'Value':'BCI_TUR'})
Turkey_CCI=df[(
    (df['LOCATION']=='TUR')   
   &(df['SUBJECT']=='CSCICP03') 
    )]
Turkey_CCI=Turkey_CCI.rename(columns = {'Value':'CCI_TUR'})
Turkey_CLI=df[(
    (df['LOCATION']=='TUR')   
   &(df['SUBJECT']=='LOLITONO') 
    )]
Turkey_CLI=Turkey_CLI.rename(columns = {'Value':'CLI_TUR'})
Turkey_GDP=df[(
    (df['LOCATION']=='TUR')   
   &(df['SUBJECT']=='LORSGPNO') 
    )]
Turkey_GDP=Turkey_GDP.rename(columns = {'Value':'GDP_TUR'})

# BCI 'BSCICP03'=>'OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
# CCI 'CSCICP03'=>'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
# CLI 'LOLITONO'=>'Normalised (CLI)'
# GDP 'LORSGPNO'=>'Normalised (GDP)'

# %%
Turkey_BCI['BCI_TUR-1'] = Turkey_BCI['BCI_TUR'].shift(1)
Turkey_BCI['BCI_TUR-2'] = Turkey_BCI['BCI_TUR'].shift(2)
Turkey_BCI['BCI_TUR-3'] = Turkey_BCI['BCI_TUR'].shift(3)
Turkey_BCI['BCI_TUR-6'] = Turkey_BCI['BCI_TUR'].shift(6)
Turkey_BCI['BCI_TUR-12'] = Turkey_BCI['BCI_TUR'].shift(12)

# %%
Turkey_CCI['CCI_TUR-1'] = Turkey_CCI['CCI_TUR'].shift(1)
Turkey_CCI['CCI_TUR-2'] = Turkey_CCI['CCI_TUR'].shift(2)
Turkey_CCI['CCI_TUR-3'] = Turkey_CCI['CCI_TUR'].shift(3)
Turkey_CCI['CCI_TUR-6'] = Turkey_CCI['CCI_TUR'].shift(6)
Turkey_CCI['CCI_TUR-12'] = Turkey_CCI['CCI_TUR'].shift(12)

# %%
Turkey_CLI['CLI_TUR-1'] = Turkey_CLI['CLI_TUR'].shift(1)
Turkey_CLI['CLI_TUR-2'] = Turkey_CLI['CLI_TUR'].shift(2)
Turkey_CLI['CLI_TUR-3'] = Turkey_CLI['CLI_TUR'].shift(3)
Turkey_CLI['CLI_TUR-6'] = Turkey_CLI['CLI_TUR'].shift(6)
Turkey_CLI['CLI_TUR-12'] = Turkey_CLI['CLI_TUR'].shift(12)

# %%
Turkey_GDP['GDP_TUR-1'] = Turkey_GDP['GDP_TUR'].shift(1)
Turkey_GDP['GDP_TUR-2'] = Turkey_GDP['GDP_TUR'].shift(2)
Turkey_GDP['GDP_TUR-3'] = Turkey_GDP['GDP_TUR'].shift(3)
Turkey_GDP['GDP_TUR-6'] = Turkey_GDP['GDP_TUR'].shift(6)
Turkey_GDP['GDP_TUR-12'] = Turkey_GDP['GDP_TUR'].shift(12)

# %%
mergedCSV = Turkey_BCI[['TIME','BCI_TUR','BCI_TUR-1','BCI_TUR-2',
                                     'BCI_TUR-3','BCI_TUR-6','BCI_TUR-12']].merge(Turkey_CCI[['TIME','CCI_TUR','CCI_TUR-1','CCI_TUR-2',
                                    'CCI_TUR-3','CCI_TUR-6','CCI_TUR-12']], 
            on = 'TIME',how = 'left').merge(Turkey_CLI[['TIME','CLI_TUR','CLI_TUR-1','CLI_TUR-2',
                                    'CLI_TUR-3','CLI_TUR-6','CLI_TUR-12']], 
            on = 'TIME',how = 'left').merge(Turkey_GDP[['TIME','GDP_TUR','GDP_TUR-1','GDP_TUR-2',
                                    'GDP_TUR-3','GDP_TUR-6','GDP_TUR-12']], 
            on = 'TIME',how = 'left')

# Convert TIME column to Date and drop N/A
mergedCSV=mergedCSV.rename(columns = {'TIME':'Date'})

for num in range(0,mergedCSV.shape[0]):
    mergedCSV.iloc[num,0]=finddate(mergedCSV.iloc[num,0])
mergedCSV=mergedCSV.dropna()

# Reindex main features for the first columns 'BCI_TUR','CCI_TUR','CLI_TUR','GDP_TUR'
mergedCSV=mergedCSV.reindex(columns=['Date', 'BCI_TUR','CCI_TUR','CLI_TUR','GDP_TUR',
                                     'BCI_TUR-1', 'BCI_TUR-2', 'BCI_TUR-3', 'BCI_TUR-6',
                                     'BCI_TUR-12','CCI_TUR-1', 'CCI_TUR-2', 'CCI_TUR-3',
                                     'CCI_TUR-6', 'CCI_TUR-12', 'CLI_TUR-1', 'CLI_TUR-2',
                                     'CLI_TUR-3', 'CLI_TUR-6', 'CLI_TUR-12', 'GDP_TUR-1',
                                     'GDP_TUR-2', 'GDP_TUR-3', 'GDP_TUR-6', 'GDP_TUR-12'])

#save resulting output file
mergedCSV.to_csv('BCI_CCI_CLI_GDP_TUR.csv',index = False)

# %%
#China_Indices
####################################

# %%
China_BCI=df[(
    (df['LOCATION']=='CHN')   
   &(df['SUBJECT']=='BSCICP03') 
    )]
China_BCI=China_BCI.rename(columns = {'Value':'BCI_CHN'})
China_CCI=df[(
    (df['LOCATION']=='CHN')   
   &(df['SUBJECT']=='CSCICP03') 
    )]
China_CCI=China_CCI.rename(columns = {'Value':'CCI_CHN'})
China_CLI=df[(
    (df['LOCATION']=='CHN')   
   &(df['SUBJECT']=='LOLITONO') 
    )]
China_CLI=China_CLI.rename(columns = {'Value':'CLI_CHN'})
China_GDP=df[(
    (df['LOCATION']=='CHN')   
   &(df['SUBJECT']=='LORSGPNO') 
    )]
China_GDP=China_GDP.rename(columns = {'Value':'GDP_CHN'})

# BCI 'BSCICP03'=>'OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
# CCI 'CSCICP03'=>'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
# CLI 'LOLITONO'=>'Normalised (CLI)'
# GDP 'LORSGPNO'=>'Normalised (GDP)'

# %%
China_BCI['BCI_CHN-1'] = China_BCI['BCI_CHN'].shift(1)
China_BCI['BCI_CHN-2'] = China_BCI['BCI_CHN'].shift(2)
China_BCI['BCI_CHN-3'] = China_BCI['BCI_CHN'].shift(3)
China_BCI['BCI_CHN-6'] = China_BCI['BCI_CHN'].shift(6)
China_BCI['BCI_CHN-12'] = China_BCI['BCI_CHN'].shift(12)

# %%
China_CCI['CCI_CHN-1'] = China_CCI['CCI_CHN'].shift(1)
China_CCI['CCI_CHN-2'] = China_CCI['CCI_CHN'].shift(2)
China_CCI['CCI_CHN-3'] = China_CCI['CCI_CHN'].shift(3)
China_CCI['CCI_CHN-6'] = China_CCI['CCI_CHN'].shift(6)
China_CCI['CCI_CHN-12'] = China_CCI['CCI_CHN'].shift(12)

# %%
China_CLI['CLI_CHN-1'] = China_CLI['CLI_CHN'].shift(1)
China_CLI['CLI_CHN-2'] = China_CLI['CLI_CHN'].shift(2)
China_CLI['CLI_CHN-3'] = China_CLI['CLI_CHN'].shift(3)
China_CLI['CLI_CHN-6'] = China_CLI['CLI_CHN'].shift(6)
China_CLI['CLI_CHN-12'] = China_CLI['CLI_CHN'].shift(12)

# %%
China_GDP['GDP_CHN-1'] = China_GDP['GDP_CHN'].shift(1)
China_GDP['GDP_CHN-2'] = China_GDP['GDP_CHN'].shift(2)
China_GDP['GDP_CHN-3'] = China_GDP['GDP_CHN'].shift(3)
China_GDP['GDP_CHN-6'] = China_GDP['GDP_CHN'].shift(6)
China_GDP['GDP_CHN-12'] = China_GDP['GDP_CHN'].shift(12)

# %%
mergedCSV = China_BCI[['TIME','BCI_CHN','BCI_CHN-1','BCI_CHN-2',
                                     'BCI_CHN-3','BCI_CHN-6','BCI_CHN-12']].merge(China_CCI[['TIME','CCI_CHN','CCI_CHN-1','CCI_CHN-2',
                                    'CCI_CHN-3','CCI_CHN-6','CCI_CHN-12']], 
            on = 'TIME',how = 'left').merge(China_CLI[['TIME','CLI_CHN','CLI_CHN-1','CLI_CHN-2',
                                    'CLI_CHN-3','CLI_CHN-6','CLI_CHN-12']], 
            on = 'TIME',how = 'left').merge(China_GDP[['TIME','GDP_CHN','GDP_CHN-1','GDP_CHN-2',
                                    'GDP_CHN-3','GDP_CHN-6','GDP_CHN-12']], 
            on = 'TIME',how = 'left')

mergedCSV=mergedCSV.rename(columns = {'TIME':'Date'})

for num in range(0,mergedCSV.shape[0]):
    mergedCSV.iloc[num,0]=finddate(mergedCSV.iloc[num,0])
mergedCSV=mergedCSV.dropna()

# Reindex main features for the first columns 'BCI_CHN','CCI_CHN','CLI_CHN','GDP_CHN',
mergedCSV=mergedCSV.reindex(columns=['Date', 'BCI_CHN','CCI_CHN','CLI_CHN','GDP_CHN',
                                     'BCI_CHN-1', 'BCI_CHN-2', 'BCI_CHN-3', 'BCI_CHN-6',
                                     'BCI_CHN-12','CCI_CHN-1', 'CCI_CHN-2', 'CCI_CHN-3',
                                     'CCI_CHN-6', 'CCI_CHN-12', 'CLI_CHN-1', 'CLI_CHN-2',
                                     'CLI_CHN-3', 'CLI_CHN-6', 'CLI_CHN-12', 'GDP_CHN-1',
                                     'GDP_CHN-2', 'GDP_CHN-3', 'GDP_CHN-6', 'GDP_CHN-12'])


#save resulting output file

mergedCSV.to_csv('BCI_CCI_CLI_GDP_CHN.csv',index = False)

# %%
mergedCSV
# Out:
#        Date    BCI_CHN    CCI_CHN    CLI_CHN   GDP_CHN  BCI_CHN-1  BCI_CHN-2  \
# 12   200102   99.76984  101.17590   98.41410  99.31998   99.52591   99.06551
# 13   200103   99.46926  101.23160   98.37440  99.21459   99.76984   99.52591
# 14   200104   98.86260  101.30660   98.33028  99.09009   99.46926   99.76984
# 15   200105   98.27046  101.35450   98.26070  98.95402   98.86260   99.46926
# 16   200106   97.91754  101.42180   98.17578  98.81464   98.27046   98.86260
# 17   200107   97.73991  101.47770   98.08656  98.67955   97.91754   98.27046
# 219   99.18719   99.34048   100.09720   99.63051   99.62549   99.62159
#
#      GDP_CHN-6  GDP_CHN-12
# 12    99.73686    99.53293
# 13    99.70493    99.57842
# 14    99.64903    99.62764
# 15    99.57498    99.67660
# 16    99.48920    99.71706
# 17    99.40094    99.74006
# 18    99.31998    99.73686
# 19    99.21459    99.70493
# 20    99.09009    99.64903
# 21    98.95402    99.57498
# 22    98.81464    99.48920
# 23    98.67955    99.40094
# 24    98.55614    99.31998
# 25    98.44874    99.21459
# 26    98.36063    99.09009
# 27    98.29642    98.95402
# 28    98.25857    98.81464
# 29    98.24381    98.67955
# 30    98.24460    98.55614
# 31    98.27753    98.44874
# 32    98.33404    98.36063
# 33    98.40318    98.29642
# 34    98.47851    98.25857
# 35    98.56190    98.24381
# 36    98.65357    98.24460
# 37    98.75323    98.27753
# 38    98.85720    98.33404
# 39    98.96310    98.40318
# 40    99.06700    98.47851
# 41    99.16035    98.56190
# ..         ...         ...
# 190   99.90251   100.26300
# 191   99.84811   100.20320
# 192   99.79662   100.14110
# 193   99.74841   100.07850
# 194   99.70346   100.01740
# 195   99.66178    99.95878
# 196   99.62280    99.90251
# 197   99.58629    99.84811
# 198   99.55247    99.79662
# 199   99.52179    99.74841
# 200   99.49417    99.70346
# 201   99.47020    99.66178
# 202   99.45055    99.62280
# 203   99.43568    99.58629
# 204   99.42588    99.55247
# 205   99.42136    99.52179
# 206   99.42267    99.49417
# 207   99.43015    99.47020
# 208   99.44363    99.45055
# 209   99.46256    99.43568
# 210   99.48547    99.42588
# 211   99.51025    99.42136
# 212   99.53429    99.42267
# 213   99.55606    99.43015
# 214   99.57441    99.44363
# 215   99.58810    99.46256
# 216   99.59769    99.48547
# 217   99.60425    99.51025
# 218   99.60866    99.53429
# 219   99.61189    99.55606
#
# [208 rows x 25 columns]

# %%
China_BCI.count()

#Turkey_Producer_Indices=Turkey_Producer_Indices.rename(columns = {'PPI_TUR_VALUE':'PPI_TUR'})
# Out:
# SUBJECT       220
# LOCATION      220
# TIME          220
# BCI_CHN       220
# BCI_CHN-1     219
# BCI_CHN-2     218
# BCI_CHN-3     217
# BCI_CHN-6     214
# BCI_CHN-12    208
# dtype: int64

# %%
#UK_Indices

# %%
UK_BCI=df[(
    (df['LOCATION']=='GBR')   
   &(df['SUBJECT']=='BSCICP03') 
    )]
UK_BCI=UK_BCI.rename(columns = {'Value':'BCI_GBR'})
UK_CCI=df[(
    (df['LOCATION']=='GBR')   
   &(df['SUBJECT']=='CSCICP03') 
    )]
UK_CCI=UK_CCI.rename(columns = {'Value':'CCI_GBR'})
UK_CLI=df[(
    (df['LOCATION']=='GBR')   
   &(df['SUBJECT']=='LOLITONO') 
    )]
UK_CLI=UK_CLI.rename(columns = {'Value':'CLI_GBR'})
UK_GDP=df[(
    (df['LOCATION']=='GBR')   
   &(df['SUBJECT']=='LORSGPNO') 
    )]
UK_GDP=UK_GDP.rename(columns = {'Value':'GDP_GBR'})

# BCI 'BSCICP03'=>'OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
# CCI 'CSCICP03'=>'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
# CLI 'LOLITONO'=>'Normalised (CLI)'
# GDP 'LORSGPNO'=>'Normalised (GDP)'

# %%
UK_BCI['BCI_GBR-1'] = UK_BCI['BCI_GBR'].shift(1)
UK_BCI['BCI_GBR-2'] = UK_BCI['BCI_GBR'].shift(2)
UK_BCI['BCI_GBR-3'] = UK_BCI['BCI_GBR'].shift(3)
UK_BCI['BCI_GBR-6'] = UK_BCI['BCI_GBR'].shift(6)
UK_BCI['BCI_GBR-12'] = UK_BCI['BCI_GBR'].shift(12)

# %%
UK_CCI['CCI_GBR-1'] = UK_CCI['CCI_GBR'].shift(1)
UK_CCI['CCI_GBR-2'] = UK_CCI['CCI_GBR'].shift(2)
UK_CCI['CCI_GBR-3'] = UK_CCI['CCI_GBR'].shift(3)
UK_CCI['CCI_GBR-6'] = UK_CCI['CCI_GBR'].shift(6)
UK_CCI['CCI_GBR-12'] = UK_CCI['CCI_GBR'].shift(12)

# %%
UK_CLI['CLI_GBR-1'] = UK_CLI['CLI_GBR'].shift(1)
UK_CLI['CLI_GBR-2'] = UK_CLI['CLI_GBR'].shift(2)
UK_CLI['CLI_GBR-3'] = UK_CLI['CLI_GBR'].shift(3)
UK_CLI['CLI_GBR-6'] = UK_CLI['CLI_GBR'].shift(6)
UK_CLI['CLI_GBR-12'] = UK_CLI['CLI_GBR'].shift(12)

# %%
UK_GDP['GDP_GBR-1'] = UK_GDP['GDP_GBR'].shift(1)
UK_GDP['GDP_GBR-2'] = UK_GDP['GDP_GBR'].shift(2)
UK_GDP['GDP_GBR-3'] = UK_GDP['GDP_GBR'].shift(3)
UK_GDP['GDP_GBR-6'] = UK_GDP['GDP_GBR'].shift(6)
UK_GDP['GDP_GBR-12'] = UK_GDP['GDP_GBR'].shift(12)

# %%
mergedCSV = UK_BCI[['TIME','BCI_GBR','BCI_GBR-1','BCI_GBR-2',
                                     'BCI_GBR-3','BCI_GBR-6','BCI_GBR-12']].merge(UK_CCI[['TIME','CCI_GBR','CCI_GBR-1','CCI_GBR-2',
                                    'CCI_GBR-3','CCI_GBR-6','CCI_GBR-12']], 
            on = 'TIME',how = 'left').merge(UK_CLI[['TIME','CLI_GBR','CLI_GBR-1','CLI_GBR-2',
                                    'CLI_GBR-3','CLI_GBR-6','CLI_GBR-12']], 
            on = 'TIME',how = 'left').merge(UK_GDP[['TIME','GDP_GBR','GDP_GBR-1','GDP_GBR-2',
                                    'GDP_GBR-3','GDP_GBR-6','GDP_GBR-12']], 
            on = 'TIME',how = 'left')

mergedCSV=mergedCSV.rename(columns = {'TIME':'Date'})

for num in range(0,mergedCSV.shape[0]):
    mergedCSV.iloc[num,0]=finddate(mergedCSV.iloc[num,0])
mergedCSV=mergedCSV.dropna()

# Reindex main features for the first columns 'BCI_GBR','CCI_GBR','CLI_GBR','GDP_GBR'
mergedCSV=mergedCSV.reindex(columns=['Date', 'BCI_GBR','CCI_GBR','CLI_GBR','GDP_GBR',
                                     'BCI_GBR-1', 'BCI_GBR-2', 'BCI_GBR-3', 'BCI_GBR-6',
                                     'BCI_GBR-12','CCI_GBR-1', 'CCI_GBR-2', 'CCI_GBR-3',
                                     'CCI_GBR-6', 'CCI_GBR-12', 'CLI_GBR-1', 'CLI_GBR-2',
                                     'CLI_GBR-3', 'CLI_GBR-6', 'CLI_GBR-12', 'GDP_GBR-1',
                                     'GDP_GBR-2', 'GDP_GBR-3', 'GDP_GBR-6', 'GDP_GBR-12'])


#save resulting output file

mergedCSV.to_csv('BCI_CCI_CLI_GDP_GBR.csv',index = False)

# %%
mergedCSV
# Out:
#        Date    BCI_GBR    CCI_GBR    CLI_GBR    GDP_GBR  BCI_GBR-1  BCI_GBR-2  \
# 12   200101  100.30760  101.15020  100.27780   99.85508  100.32690  100.16890
# 13   200102  100.02120  101.05670  100.30690   99.90983  100.30760  100.32690
# 14   200103   99.66763  101.01640  100.29640   99.96222  100.02120  100.30760
# 15   200104   99.50746  100.98270  100.26940  100.00170   99.66763  100.02120
# 16   200105   99.48422  101.02320  100.22500  100.02320   99.50746   99.66763
# 17   200106   99.59045  101.12020  100.14580  100.02430   99.48422   99.50746
# 18   200107   99.52011  101.00670  100.02400  100.00410   99.59045   99.48422
# 19   200108   99.31445  100.62740   99.88567   99.96257   99.52011   99.59045
# 20   200109   99.04087  100.25170   99.77824   99.90109   99.31445   99.52011
# 21   200110   98.69973   99.90818   99.72504   99.82523   99.04087   99.31445
# 22   200111   98.36401   99.91476   99.76053   99.74203   98.69973   99.04087
# 23   200112   98.13914  100.12180   99.87586   99.65861   98.36401   98.69973
# 24   200201   98.27210  100.40170  100.05800   99.58122   98.13914   98.36401
# 25   200202   98.61375  100.62760  100.26000   99.51512   98.27210   98.13914
# 26   200203   98.99074  100.78100  100.43210   99.46395   98.61375   98.27210
# 27   200204   99.36884  100.91210  100.53730   99.42846   98.99074   98.61375
# 28   200205   99.63046  100.93990  100.53600   99.40814   99.36884   98.99074
# 29   200206   99.81477  100.92400  100.44230   99.40186   99.63046   99.36884
# 30   200207   99.88705  100.97500  100.30160   99.40735   99.81477   99.63046
# 31   200208   99.86345  101.11510  100.14040   99.42197   99.88705   99.81477
# 32   200209   99.72840  101.21180   99.96210   99.44267   99.86345   99.88705
# 33   200210   99.66436  101.14760   99.76081   99.46527   99.72840   99.86345
# 34   200211   99.60976  100.92510   99.52545   99.48652   99.66436   99.72840
# 35   200212   99.45706  100.48300   99.27325   99.50594   99.60976   99.66436
# 36   200301   99.30309  100.10470   99.04982   99.52789   99.45706   99.60976
# 37   200302   99.18961   99.91474   98.89540   99.55859   99.30309   99.45706
# 38   200303   99.09239   99.94720   98.83001   99.60316   99.18961   99.30309
# 39   200304   98.94197  100.18050   98.87209   99.66197   99.09239   99.18961
# 40   200305   98.80333  100.41220   99.00787   99.73245   98.94197   99.09239
# 41   200306   98.75835  100.55210   99.19776   99.80992   98.80333   98.94197
# ..      ...        ...        ...        ...        ...        ...        ...
