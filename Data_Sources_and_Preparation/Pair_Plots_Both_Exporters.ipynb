# %% [markdown]
# For Products : 841810 841840 and 841850
# China to UK Prediction
# and
# Turkey to UK Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from sklearn.cross_validation import train_test_split
import seaborn as sns
# %matplotlib inline

# %%
import sys
import warnings
import os
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
os.getcwd()
# Out:
# 'C:\\Users\\murat.ozemre\\Desktop\\Thesis_Project\\Data_Sources_and_Preparation'

# %%
Product=841850

Productname=Product
Exp_Country='CHN' # 'CHN'
Imp_Country='GBR'

if Exp_Country=='CHN':
    Currency='CNY'
    EXP0='TUR'   
elif Exp_Country=='TUR':
    Currency='TRY'
    EXP0='CHN'

# %%
MonthSeries=''

# %%
#os.chdir('..')
#os.chdir('Data_Sources_and_Preparation')

Data_Core1 = pd.ExcelFile('Data_{}_{}_{}.xlsx'.format(Exp_Country,Imp_Country,Product))
y = Data_Core1.parse('Y', header=0,index_col=None, na_values=['NA'])['{}_{}_{}'.format(Exp_Country,Imp_Country,Product)]
Z = Data_Core1.parse('Y', header=0,index_col=None, na_values=['NA'])[['Date','Year','Month']]

X = Data_Core1.parse('X{}'.format(MonthSeries), header=0,index_col=None, na_values=['NA'])
X.drop(['Date','Year','Month'], axis=1, inplace=True)
X_Column_Names=list(X.columns.values)
n_feature=X.shape[1]


number_of_column=X.shape[1]
number_of_row=X.shape[0]

# %%
IMP1=X.columns.values.tolist()[2].split('_')[1]
IMP2=X.columns.values.tolist()[3].split('_')[1]
IMP3=X.columns.values.tolist()[4].split('_')[1]
IMP4=X.columns.values.tolist()[5].split('_')[1]

EXP1=X.columns.values.tolist()[6].split('_')[0]
EXP2=X.columns.values.tolist()[7].split('_')[0]
EXP3=X.columns.values.tolist()[8].split('_')[0]
EXP4=X.columns.values.tolist()[9].split('_')[0]

# %% [markdown]
# # Pair Plots for combined data sets.

# %%
#PairPlot for CHINA Exports to GBR and Political Uncertainity

if Exp_Country=='TUR':
       sns_plot =  sns.pairplot(X , 
           
           x_vars=[
               #'EPU_{}-1'.format(Exp_Country),
               'EPU_{}'.format(Imp_Country), 
               'EPU_World'
           ],
            y_vars= [
            '{}_{}_{}'.format(Exp_Country,Imp_Country,Product)
            ],
   # hue='Month' ,  
            diag_kind="kde") 
           
        
elif Exp_Country=='CHN':        
     sns_plot = sns.pairplot(X , 
           
           x_vars=[
               'EPU_{}'.format(Exp_Country),
               'EPU_{}'.format(Imp_Country), 
               'EPU_World'
           ],
            y_vars= [
            '{}_{}_{}'.format(Exp_Country,Imp_Country,Product)
            ],
   # hue='Month' ,  
            diag_kind="kde")
         
        
sns_plot.savefig('Plots_Data_Consolidation_Pair_Plots\Politic_Uncertainity_Pair_Plot_{}_{}_{}.png'.format(Exp_Country,Imp_Country,Product))

# %%
# Pairplots Exporters (Turkey or China)  Exports to GBR and its top 5 markets
    
sns_plot = sns.pairplot(X ,  
    
    x_vars=['{}_World_{}'.format(Exp_Country,Product),  
            '{}_{}_{}'.format(Exp_Country,IMP1,Product), 
            '{}_{}_{}'.format(Exp_Country,IMP2,Product),
            '{}_{}_{}'.format(Exp_Country,IMP3,Product), 
            '{}_{}_{}'.format(Exp_Country,IMP4,Product),
           ],
    y_vars= [
            '{}_{}_{}'.format(Exp_Country,Imp_Country,Product)
            ],
   # hue='Month' ,  
            diag_kind="kde") 
    

sns_plot.savefig('Plots_Data_Consolidation_Pair_Plots\Importers_Pair_Plot_{}_{}_{}.png'.format(Exp_Country,Imp_Country,Product))

# %%
sns_plot = sns.pairplot(X ,  
    
    x_vars=[ '{}_{}_{}'. format(EXP1,Imp_Country,Product), 
            '{}_{}_{}'. format(EXP2,Imp_Country,Product), 
            '{}_{}_{}'. format(EXP3,Imp_Country,Product), 
            '{}_{}_{}'. format(EXP4,Imp_Country,Product),
           ],
    y_vars= [
            '{}_{}_{}'.format(Exp_Country,Imp_Country,Product)
            ],
   # hue='Month' ,  
            diag_kind="kde") 
    

sns_plot.savefig('Plots_Data_Consolidation_Pair_Plots\Exporters_Pair_Plot_{}_{}_{}.png'.format(Exp_Country,Imp_Country,Product))

# %%
sns_plot = sns.pairplot(X ,  
    
    x_vars=[ 'BCI_{}'.format(Exp_Country), 
             'CCI_{}'.format(Exp_Country),
             'CLI_{}'.format(Exp_Country)
                   ],
    y_vars= [
            '{}_{}_{}'.format(Exp_Country,Imp_Country,Product)
            ],
   # hue='Month' ,  
            diag_kind="kde") 
    

sns_plot.savefig('Plots_Data_Consolidation_Pair_Plots\Exporters_BCI_CCI_CLI_Pair_Plot_{}_{}_{}.png'.format(Exp_Country,Imp_Country,Product))

# %%
sns_plot = sns.pairplot(X ,  
    
    x_vars=[ 'BCI_{}'.format(Imp_Country), 
             'CCI_{}'.format(Imp_Country),
             'CLI_{}'.format(Imp_Country)
                   ],
    y_vars= [
            '{}_{}_{}'.format(Exp_Country,Imp_Country,Product)
            ],
   # hue='Month' ,  
            diag_kind="kde") 
    

sns_plot.savefig('Plots_Data_Consolidation_Pair_Plots\Importers_BCI_CCI_CLI_Pair_Plot_{}_{}_{}.png'.format(Exp_Country,Imp_Country,Product))

# %%
sns_plot = sns.pairplot(X ,  
    
    x_vars=[ 'GDP_{}'.format(Imp_Country), 
             'PPI_{}'.format(Imp_Country),
             'CPI_{}'.format(Imp_Country),
             'GBP'
                   ],
    y_vars= [
            '{}_{}_{}'.format(Exp_Country,Imp_Country,Product)
            ],
   # hue='Month' ,  
            diag_kind="kde") 
    

sns_plot.savefig('Plots_Data_Consolidation_Pair_Plots\Importers_GDP_PPI_CPI_GBP_Pair_Plot_{}_{}_{}.png'.format(Exp_Country,Imp_Country,Product))

# %%
sns_plot = sns.pairplot(X ,  
    
    x_vars=[ 'GDP_{}'.format(Exp_Country), 
             'PPI_{}'.format(Exp_Country),
             'CPI_{}'.format(Exp_Country),
             '{}'.format(Currency)
                   ],
    y_vars= [
            '{}_{}_{}'.format(Exp_Country,Imp_Country,Product)
            ],
   # hue='Month' ,  
            diag_kind="kde") 
    

sns_plot.savefig('Plots_Data_Consolidation_Pair_Plots\Exporters_GDP_PPI_CPI_Pair_Plot_{}_{}_{}.png'.format(Exp_Country,Imp_Country,Product))

# %%
import pandas as pd
from random import gauss
from random import seed
from pandas import Series
from matplotlib import pyplot

# %%
def format_func(value, tick_number):
    # find number of multiples of pi/2
    N = tick_number # int(np.round(2 * value / np.pi))
    
    if N == 1:
        return "200604"
    elif N == 2:
        return "200712"
    elif N == 3:
        return "200908"
    elif N ==4: 
        return "201104"
    elif N == 5:
        return "201212"
    elif N == 6:
        return "201408"
    elif N == 7: 
        return "201604"
    elif N == 8: 
        return "201712"
    else:
        return ""

# %%
for i in range(number_of_column):

    z=X.iloc[:,i]
    window_size=12

    rolling_mean = z.rolling(12).mean()
    pyplot.gcf().clear()
    
    fig = plt.figure(figsize=(15, 5))

    ax = plt.axes()
    x= Z['Date'][:number_of_row]
    xi = [i for i in range(0, len(x))]
    
    ax.plot(xi, z, lw=2, color='darkslateblue',label='{}'.format(z.name))
    ax.plot(xi, rolling_mean, lw=2, color='crimson', label='Moving Average')
    ax.grid(True)
    ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
    ax.legend(frameon=True)
    plt.title(" {} - Line Plot".format(z.name), fontsize=20)
    plt.xlabel('Year Month')
    plt.savefig('Plots_Features\{} - Feature Plots.png'.format(z.name), format='png', dpi=300)

# %%
def format_func(value, tick_number):
    # find number of multiples of pi/2
    N = tick_number # int(np.round(2 * value / np.pi))
    
    if N == 1:
        return "200607"
    elif N == 2:
        return "200803"
    elif N == 3:
        return "200911"
    elif N ==4: 
        return "201107"
    elif N == 5:
        return "201303"
    elif N == 6:
        return "201411"
    elif N == 7: 
        return "201607"
    elif N == 8: 
        return "201803"
    else:
        return ""

# %%
z=y
window_size=12

rolling_mean = z.rolling(12).mean()
pyplot.gcf().clear()
    
fig = plt.figure(figsize=(15, 5))

ax = plt.axes()
x = Z['Date']
xi = [i for i in range(0, len(x))]
    
ax.plot(xi, z, lw=2, color='darkslateblue',label='{}'.format(z.name))
ax.plot(xi, rolling_mean, lw=2, color='crimson', label='Moving Average')

ax.grid(True)
ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
ax.legend(frameon=True)
plt.title(" {} - Line Plot".format(z.name), fontsize=20)
plt.xlabel('Year Month')
plt.savefig('Plots_Features\Main_Plots\{} - Feature Plots.png'.format(z.name), format='png', dpi=300)

# %%
range(0, len(x))
# Out:
# range(0, 137)

# %%
x
# Out:
# 0      200607
# 1      200608
# 2      200609
# 3      200610
# 4      200611
# 5      200612
# 6      200701
# 7      200702
# 8      200703
# 9      200704
# 10     200705
# 11     200706
# 12     200707
# 13     200708
# 14     200709
# 15     200710
# 16     200711
# 17     200712
# 18     200801
# 19     200802
# 20     200803
# 21     200804
# 22     200805
# 23     200806
# 24     200807
# 25     200808
# 26     200809
# 27     200810
# 28     200811
# 29     200812
#         ...
# 107    201508
# 108    201509
# 109    201510
# 110    201511
# 111    201512
# 112    201601
# 113    201602
# 114    201603
# 115    201604
# 116    201605
# 117    201606
# 118    201607
# 119    201608
# 120    201609
# 121    201610
# 122    201611
# 123    201612
# 124    201701
# 125    201702
# 126    201703
# 127    201704
# 128    201705
# 129    201706
# 130    201707
# 131    201708
# 132    201709
# 133    201710
# 134    201711
# 135    201712
# 136    201801
# ...
