# %%
import numpy as np
import pandas as pd

# %%
xls = pd.ExcelFile('Global_Trade_Data\Global Trade May 2018.xlsx')
WorldTrade = xls.parse('World', header=0,index_col=None, na_values=['NA'])
#WorldTrade = xls.parse('World', skiprows=9, header=0,index_col=None, na_values=['NA'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\murat.ozemre\AppData\Local\Continuum\Anaconda3\envs\Tensor\lib\site-packages\xlrd\book.py in sheet_by_name(self, sheet_name)
#     438         try:
# --> 439             sheetx = self._sheet_names.index(sheet_name)
#     440         except ValueError:
#
# ValueError: 'World' is not in list
#
# During handling of the above exception, another exception occurred:
#
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-2-61e446ac1a43> in <module>()
#       2
#       3 xls = pd.ExcelFile('Global_Trade_Data\Global Trade May 2018.xlsx')
# ----> 4 WorldTrade = xls.parse('World', header=0,index_col=None, na_values=['NA'])
#       5 #WorldTrade = xls.parse('World', skiprows=9, header=0,index_col=None, na_values=['NA'])
#
# C:\Users\murat.ozemre\AppData\Local\Continuum\Anaconda3\envs\Tensor\lib\site-packages\pandas\io\excel.py in parse(self, sheetname, header, skiprows, skip_footer, names, index_col, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, true_values, false_values, squeeze, **kwds)
#     287                                  false_values=false_values,
#     288                                  squeeze=squeeze,
# --> 289                                  **kwds)
#     290
#     291     def _should_parse(self, i, parse_cols):
#
# C:\Users\murat.ozemre\AppData\Local\Continuum\Anaconda3\envs\Tensor\lib\site-packages\pandas\io\excel.py in _parse_excel(self, sheetname, header, skiprows, names, skip_footer, index_col, has_index_names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, true_values, false_values, verbose, dtype, squeeze, **kwds)
#     433
#     434             if isinstance(asheetname, compat.string_types):
# --> 435                 sheet = self.book.sheet_by_name(asheetname)
#     436             else:  # assume an integer if not a string
#     437                 sheet = self.book.sheet_by_index(asheetname)
#
# C:\Users\murat.ozemre\AppData\Local\Continuum\Anaconda3\envs\Tensor\lib\site-packages\xlrd\book.py in sheet_by_name(self, sheet_name)
#     439             sheetx = self._sheet_names.index(sheet_name)
#     440         except ValueError:
# --> 441             raise XLRDError('No sheet named <%r>' % sheet_name)
#     442         return self.sheet_by_index(sheetx)
#     443
#
# XLRDError: No sheet named <'World'>

# %%
WorldTrade
# Out:
#        Date       World
# 0    200001   64.554286
# 1    200002   65.614573
# 2    200003   65.721381
# 3    200004   66.336496
# 4    200005   68.283152
# 5    200006   67.229168
# 6    200007   68.221316
# 7    200008   69.392481
# 8    200009   69.314872
# 9    200010   70.237382
# 10   200011   70.443515
# 11   200012   70.512641
# 12   200101   70.331213
# 13   200102   69.446796
# 14   200103   69.163815
# 15   200104   68.477830
# 16   200105   68.041011
# 17   200106   67.942095
# 18   200107   67.135612
# 19   200108   67.278883
# 20   200109   66.225091
# 21   200110   67.137473
# 22   200111   66.861210
# 23   200112   65.962935
# 24   200201   67.218701
# 25   200202   68.012068
# 26   200203   68.374025
# 27   200204   69.435834
# 28   200205   68.840980
# 29   200206   70.084333
# ..      ...         ...
# 180  201501  114.279030
# 181  201502  113.918560
# 182  201503  112.575190
# 183  201504  112.783208
# 184  201505  111.438026
# 185  201506  113.094886
# 186  201507  113.560781
# 187  201508  113.434006
# 188  201509  113.888480
# 189  201510  114.517489
# 190  201511  114.012588
# 191  201512  115.094707
# 192  201601  114.058995
# 193  201602  115.294425
# 194  201603  113.514744
# 195  201604  114.128176
# 196  201605  113.629340
# 197  201606  115.058825
# 198  201607  113.591240
# 199  201608  115.869729
# 200  201609  115.261822
# 201  201610  114.598572
# 202  201611  117.738560
# 203  201612  118.722314
# 204  201701  118.603252
# 205  201702  117.386394
# 206  201703  120.052127
# 207  201704  117.451510
# 208  201705  119.723932
# 209  201706  120.381532
#
# [210 rows x 2 columns]

# %%
#Zaman Kaydırması Yapmak için kullanıyor. 
#Butun veri zaman ekseni açısından tam ve sıralandıktan sonra yapılması gerekiyor
WorldTrade['World-1'] = WorldTrade['World'].shift(1)
WorldTrade['World-2'] = WorldTrade['World'].shift(2)
WorldTrade['World-3'] = WorldTrade['World'].shift(3)
WorldTrade['World-6'] = WorldTrade['World'].shift(6)
WorldTrade['World-12'] = WorldTrade['World'].shift(12)

# %%
WorldTrade
# Out:
#        Date       World     World-1     World-2     World-3     World-6  \
# 0    200001   64.554286         NaN         NaN         NaN         NaN
# 1    200002   65.614573   64.554286         NaN         NaN         NaN
# 2    200003   65.721381   65.614573   64.554286         NaN         NaN
# 3    200004   66.336496   65.721381   65.614573   64.554286         NaN
# 4    200005   68.283152   66.336496   65.721381   65.614573         NaN
# 5    200006   67.229168   68.283152   66.336496   65.721381         NaN
# 6    200007   68.221316   67.229168   68.283152   66.336496   64.554286
# 7    200008   69.392481   68.221316   67.229168   68.283152   65.614573
# 8    200009   69.314872   69.392481   68.221316   67.229168   65.721381
# 9    200010   70.237382   69.314872   69.392481   68.221316   66.336496
# 10   200011   70.443515   70.237382   69.314872   69.392481   68.283152
# 11   200012   70.512641   70.443515   70.237382   69.314872   67.229168
# 12   200101   70.331213   70.512641   70.443515   70.237382   68.221316
# 13   200102   69.446796   70.331213   70.512641   70.443515   69.392481
# 14   200103   69.163815   69.446796   70.331213   70.512641   69.314872
# 15   200104   68.477830   69.163815   69.446796   70.331213   70.237382
# 16   200105   68.041011   68.477830   69.163815   69.446796   70.443515
# 17   200106   67.942095   68.041011   68.477830   69.163815   70.512641
# 18   200107   67.135612   67.942095   68.041011   68.477830   70.331213
# 19   200108   67.278883   67.135612   67.942095   68.041011   69.446796
# 20   200109   66.225091   67.278883   67.135612   67.942095   69.163815
# 21   200110   67.137473   66.225091   67.278883   67.135612   68.477830
# 22   200111   66.861210   67.137473   66.225091   67.278883   68.041011
# 23   200112   65.962935   66.861210   67.137473   66.225091   67.942095
# 24   200201   67.218701   65.962935   66.861210   67.137473   67.135612
# 25   200202   68.012068   67.218701   65.962935   66.861210   67.278883
# 26   200203   68.374025   68.012068   67.218701   65.962935   66.225091
# 27   200204   69.435834   68.374025   68.012068   67.218701   67.137473
