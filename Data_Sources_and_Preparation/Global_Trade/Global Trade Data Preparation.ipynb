# %%
import numpy as np
import pandas as pd

# %%
xls = pd.ExcelFile('Global_Trade_Data\Global Trade May 2018.xlsx')
WorldTrade = xls.parse('World', header=0,index_col=None, na_values=['NA'])
#WorldTrade = xls.parse('World', skiprows=9, header=0,index_col=None, na_values=['NA'])

# %%
WorldTrade=WorldTrade.reindex(columns=['World','Date'])

# %%
#Zaman Kaydırması Yapmak için kullanıyor. 
#Butun veri zaman ekseni açısından tam ve sıralandıktan sonra yapılması gerekiyor
WorldTrade['World-1'] = WorldTrade['World'].shift(1)
WorldTrade['World-2'] = WorldTrade['World'].shift(2)
WorldTrade['World-3'] = WorldTrade['World'].shift(3)
WorldTrade['World-4'] = WorldTrade['World'].shift(4)
WorldTrade['World-5'] = WorldTrade['World'].shift(5)
WorldTrade['World-6'] = WorldTrade['World'].shift(6)
WorldTrade['World-7'] = WorldTrade['World'].shift(7)
WorldTrade['World-8'] = WorldTrade['World'].shift(8)
WorldTrade['World-12'] = WorldTrade['World'].shift(12)

# %%
WorldTrade
# Out:
#           World    Date     World-1     World-2     World-3     World-4  \
# 0     63.799956  200001         NaN         NaN         NaN         NaN
# 1     64.886562  200002   63.799956         NaN         NaN         NaN
# 2     64.968500  200003   64.886562   63.799956         NaN         NaN
# 3     65.591692  200004   64.968500   64.886562   63.799956         NaN
# 4     67.567767  200005   65.591692   64.968500   64.886562   63.799956
# 5     66.451285  200006   67.567767   65.591692   64.968500   64.886562
# 6     67.502041  200007   66.451285   67.567767   65.591692   64.968500
# 7     68.653621  200008   67.502041   66.451285   67.567767   65.591692
# 8     68.600649  200009   68.653621   67.502041   66.451285   67.567767
# 9     69.500291  200010   68.600649   68.653621   67.502041   66.451285
# 10    69.718706  200011   69.500291   68.600649   68.653621   67.502041
# 11    69.869123  200012   69.718706   69.500291   68.600649   68.653621
# ...

# %%
#save resulting output file

WorldTrade.to_csv('WorldTrade.csv',index = False)
