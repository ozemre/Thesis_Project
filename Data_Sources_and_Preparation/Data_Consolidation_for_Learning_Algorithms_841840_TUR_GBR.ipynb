# %% [markdown]
# 841840 Turkey to UK Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\murat.ozemre\AppData\Local\Continuum\Anaconda3\envs\Tensor\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
# Reading Excel Files

# %%
ITC_DF1 = pd.ExcelFile('ITC_Trade_Data\841840_Tur_all.xlsx')
ITC_DF1 = ITC_DF1.parse('Sheet1', header=0,index_col=None, na_values=['NA'])

# %%
ITC_DF1.columns
# Out:
# Index(['TUR_World_841840', 'TUR_USA_841840', 'TUR_GBR_841840',
#        'TUR_FRA_841840', 'TUR_DEU_841840', 'TUR_SWE_841840', 'Date',
#        'TUR_World_841840-1', 'TUR_World_841840-2', 'TUR_World_841840-3',
#        'TUR_World_841840-6', 'TUR_World_841840-12', 'TUR_USA_841840-1',
#        'TUR_USA_841840-2', 'TUR_USA_841840-3', 'TUR_USA_841840-6',
#        'TUR_USA_841840-12', 'TUR_DEU_841840-1', 'TUR_DEU_841840-2',
#        'TUR_DEU_841840-3', 'TUR_DEU_841840-6', 'TUR_DEU_841840-12',
#        'TUR_FRA_841840-1', 'TUR_FRA_841840-2', 'TUR_FRA_841840-3',
#        'TUR_FRA_841840-6', 'TUR_FRA_841840-12', 'TUR_GBR_841840-1',
#        'TUR_GBR_841840-2', 'TUR_GBR_841840-3', 'TUR_GBR_841840-6',
#        'TUR_GBR_841840-12', 'TUR_SWE_841840-1', 'TUR_SWE_841840-2',
#        'TUR_SWE_841840-3', 'TUR_SWE_841840-6', 'TUR_SWE_841840-12'],
#       dtype='object')

# %%
ITC_DF2 = pd.ExcelFile('ITC_Trade_Data\841840_UK_all.xlsx')
ITC_DF2 = ITC_DF2.parse('Sheet1', header=0,index_col=None, na_values=['NA'])
ITC_DF2.columns
# Out:
# Index(['TUR_GBR_841840', 'CHN_GBR_841840', 'DEU_GBR_841840', 'HUN_GBR_841840',
#        'NLD_GBR_841840', 'Date', 'TUR_GBR_841840-1', 'TUR_GBR_841840-2',
#        'TUR_GBR_841840-3', 'TUR_GBR_841840-6', 'TUR_GBR_841840-12',
#        'CHN_GBR_841840-1', 'CHN_GBR_841840-2', 'CHN_GBR_841840-3',
#        'CHN_GBR_841840-6', 'CHN_GBR_841840-12', 'DEU_GBR_841840-1',
#        'DEU_GBR_841840-2', 'DEU_GBR_841840-3', 'DEU_GBR_841840-6',
#        'DEU_GBR_841840-12', 'NLD_GBR_841840-1', 'NLD_GBR_841840-2',
#        'NLD_GBR_841840-3', 'NLD_GBR_841840-6', 'NLD_GBR_841840-12',
#        'HUN_GBR_841840-1', 'HUN_GBR_841840-2', 'HUN_GBR_841840-3',
#        'HUN_GBR_841840-6', 'HUN_GBR_841840-12'],
#       dtype='object')

# %%
#EPU_DF1 = pd.ExcelFile('Economic_Uncertainty\EPU_CHN.xlsx')
#EPU_DF1 = EPU_DF1.parse('Sheet1', header=0,index_col=None, na_values=['NA'])
#EPU_DF1.columns

# %%
EPU_DF2 = pd.ExcelFile('Economic_Uncertainty\EPU_UK.xlsx')
EPU_DF2 = EPU_DF2.parse('Sheet1', header=0,index_col=None, na_values=['NA'])
EPU_DF2.columns
# Out:
# Index(['Date', 'EPU_UK', 'EPU_UK-1', 'EPU_UK-2', 'EPU_UK-3', 'EPU_UK-6',
#        'EPU_UK-12'],
#       dtype='object')

# %%
EPU_World = pd.ExcelFile('Economic_Uncertainty\EPU_World.xlsx')
EPU_World = EPU_World.parse('Sheet1', header=0,index_col=None, na_values=['NA'])
EPU_World.columns
# Out:
# Index(['Date', 'EPU_World', 'EPU_World-1', 'EPU_World-2', 'EPU_World-3',
#        'EPU_World-6', 'EPU_World-12'],
#       dtype='object')

# %%
# Reading Related CSV Files

# %%
OECD_DF1 = pd.read_csv('OECD\BCI_CCI_CLI_GDP_TUR.csv')
OECD_DF1.columns
# Out:
# Index(['Date', 'BCI_TUR', 'BCI_TUR-1', 'BCI_TUR-2', 'BCI_TUR-3', 'BCI_TUR-6',
#        'BCI_TUR-12', 'CCI_TUR', 'CCI_TUR-1', 'CCI_TUR-2', 'CCI_TUR-3',
#        'CCI_TUR-6', 'CCI_TUR-12', 'CLI_TUR', 'CLI_TUR-1', 'CLI_TUR-2',
#        'CLI_TUR-3', 'CLI_TUR-6', 'CLI_TUR-12', 'GDP_TUR', 'GDP_TUR-1',
#        'GDP_TUR-2', 'GDP_TUR-3', 'GDP_TUR-6', 'GDP_TUR-12'],
#       dtype='object')

# %%
OECD_DF2 = pd.read_csv('OECD\BCI_CCI_CLI_GDP_GBR.csv')
OECD_DF2.columns
# Out:
# Index(['Date', 'BCI_GBR', 'BCI_GBR-1', 'BCI_GBR-2', 'BCI_GBR-3', 'BCI_GBR-6',
#        'BCI_GBR-12', 'CCI_GBR', 'CCI_GBR-1', 'CCI_GBR-2', 'CCI_GBR-3',
#        'CCI_GBR-6', 'CCI_GBR-12', 'CLI_GBR', 'CLI_GBR-1', 'CLI_GBR-2',
#        'CLI_GBR-3', 'CLI_GBR-6', 'CLI_GBR-12', 'GDP_GBR', 'GDP_GBR-1',
#        'GDP_GBR-2', 'GDP_GBR-3', 'GDP_GBR-6', 'GDP_GBR-12'],
#       dtype='object')

# %%
#OECD_DF3 = pd.read_csv('OECD\PPI_CHN_UK.csv')
#OECD_DF3.columns

# %%
OECD_DF4 = pd.read_csv('OECD\CPI_TUR_UK.csv')
OECD_DF4.columns
# Out:
# Index(['Date', 'CPI_TUR', 'CPI_TUR-1', 'CPI_TUR-2', 'CPI_TUR-3', 'CPI_TUR-6',
#        'CPI_TUR-12', 'CPI_GBR', 'CPI_GBR-1', 'CPI_GBR-2', 'CPI_GBR-3',
#        'CPI_GBR-6', 'CPI_GBR-12'],
#       dtype='object')

# %%
OECD_DF5 = pd.read_csv('OECD\TRY_GBP.csv')
OECD_DF5.columns
# Out:
# Index(['Date', 'TRY', 'TRY-1', 'TRY-2', 'TRY-3', 'TRY-6', 'TRY-12', 'GBP',
#        'GBP-1', 'GBP-2', 'GBP-3', 'GBP-6', 'GBP-12'],
#       dtype='object')

# %%
OTHER_DF1 = pd.read_csv('Global_Trade\WorldTrade.csv')
OTHER_DF1.columns
# Out:
# Index(['Date', 'World', 'World-1', 'World-2', 'World-3', 'World-6',
#        'World-12'],
#       dtype='object')

# %%
# Data_Core for the current month
Data_Core = ITC_DF1[['TUR_World_841840', 'TUR_USA_841840', 'TUR_GBR_841840',
       'TUR_FRA_841840', 'TUR_DEU_841840', 'TUR_SWE_841840', 'Date']].merge(ITC_DF2[['Date','CHN_GBR_841840', 'DEU_GBR_841840', 'HUN_GBR_841840',
       'NLD_GBR_841840' ]], 
#                        on = 'Date',how = 'left').merge(EPU_DF1[['Date', 'EPU_CHN'      ]],
                        on = 'Date',how = 'left').merge(EPU_DF2[['Date', 'EPU_UK'      ]], 
                        on = 'Date',how = 'left').merge(EPU_World[['Date','EPU_World']],
                        on = 'Date',how = 'left').merge(OECD_DF1[['Date','BCI_TUR','CCI_TUR','CLI_TUR','GDP_TUR']], 
                        on = 'Date',how = 'left').merge(OECD_DF2[['Date','BCI_GBR','CCI_GBR','CLI_GBR','GDP_GBR']], 
#                        on = 'Date',how = 'left').merge(OECD_DF3[['Date','PPI_CHN', 'PPI_GBR']], 
                        on = 'Date',how = 'left').merge(OECD_DF4[['Date','CPI_TUR','CPI_GBR']], 
                        on = 'Date',how = 'left').merge(OECD_DF5[['Date','TRY','GBP']], 
                        on = 'Date',how = 'left').merge(OTHER_DF1[['Date','World']], 
                        on = 'Date',how = 'left')
#Data_Core=Data_Core.dropna()
print(Data_Core.columns,Data_Core.shape)
# Out:
# Index(['TUR_World_841840', 'TUR_USA_841840', 'TUR_GBR_841840',
#        'TUR_FRA_841840', 'TUR_DEU_841840', 'TUR_SWE_841840', 'Date',
#        'CHN_GBR_841840', 'DEU_GBR_841840', 'HUN_GBR_841840', 'NLD_GBR_841840',
#        'EPU_UK', 'EPU_World', 'BCI_TUR', 'CCI_TUR', 'CLI_TUR', 'GDP_TUR',
#        'BCI_GBR', 'CCI_GBR', 'CLI_GBR', 'GDP_GBR', 'CPI_TUR', 'CPI_GBR', 'TRY',
#        'GBP', 'World'],
#       dtype='object') (136, 26)

# %%
# Data_Core for Y current month and X for the previous month
Data_Core_1 = ITC_DF1[[ 'TUR_GBR_841840','TUR_World_841840-1', 'TUR_USA_841840-1', 'TUR_GBR_841840-1',
       'TUR_FRA_841840-1', 'TUR_DEU_841840-1', 'TUR_SWE_841840-1',
                       'Date']].merge(ITC_DF2[['Date','CHN_GBR_841840-1', 'DEU_GBR_841840-1', 'HUN_GBR_841840-1', 'NLD_GBR_841840-1' ]], 
#                        on = 'Date',how = 'left').merge(EPU_DF1[['Date', 'EPU_CHN-1'      ]],
                        on = 'Date',how = 'left').merge(EPU_DF2[['Date', 'EPU_UK-1'      ]], 
                        on = 'Date',how = 'left').merge(EPU_World[['Date','EPU_World-1']],
                        on = 'Date',how = 'left').merge(OECD_DF1[['Date','BCI_TUR-1','CCI_TUR-1','CLI_TUR-1','GDP_TUR-1']], 
                        on = 'Date',how = 'left').merge(OECD_DF2[['Date','BCI_GBR-1','CCI_GBR-1','CLI_GBR-1','GDP_GBR-1']], 
#                        on = 'Date',how = 'left').merge(OECD_DF3[['Date','PPI_CHN-1', 'PPI_GBR-1']], 
                        on = 'Date',how = 'left').merge(OECD_DF4[['Date','CPI_TUR-1','CPI_GBR-1']], 
                        on = 'Date',how = 'left').merge(OECD_DF5[['Date','TRY-1','GBP-1']], 
                        on = 'Date',how = 'left').merge(OTHER_DF1[['Date','World-1']], 
                        on = 'Date',how = 'left')
#Data_Core_1=Data_Core_1.dropna()
Data_Core_1=Data_Core_1.fillna(0)
print(Data_Core_1.columns,Data_Core_1.shape)
# Out:
# Index(['TUR_GBR_841840', 'TUR_World_841840-1', 'TUR_USA_841840-1',
#        'TUR_GBR_841840-1', 'TUR_FRA_841840-1', 'TUR_DEU_841840-1',
#        'TUR_SWE_841840-1', 'Date', 'CHN_GBR_841840-1', 'DEU_GBR_841840-1',
#        'HUN_GBR_841840-1', 'NLD_GBR_841840-1', 'EPU_UK-1', 'EPU_World-1',
#        'BCI_TUR-1', 'CCI_TUR-1', 'CLI_TUR-1', 'GDP_TUR-1', 'BCI_GBR-1',
#        'CCI_GBR-1', 'CLI_GBR-1', 'GDP_GBR-1', 'CPI_TUR-1', 'CPI_GBR-1',
#        'TRY-1', 'GBP-1', 'World-1'],
#       dtype='object') (136, 27)

# %%
# Data_Core for Y current month and X for the previous months (-1, -2, -3, -6 and -12 months)
Data_Core_1236_12 = ITC_DF1[['TUR_GBR_841840',
                        
                        'TUR_World_841840-1', 'TUR_USA_841840-1', 'TUR_GBR_841840-1',
                        'TUR_FRA_841840-1', 'TUR_DEU_841840-1', 'TUR_SWE_841840-1',
                                  
                        'TUR_World_841840-2', 'TUR_USA_841840-2', 'TUR_GBR_841840-2',
                        'TUR_FRA_841840-2', 'TUR_DEU_841840-2', 'TUR_SWE_841840-2',
                        
                        'TUR_World_841840-3', 'TUR_USA_841840-3', 'TUR_GBR_841840-3',
                        'TUR_FRA_841840-3', 'TUR_DEU_841840-3', 'TUR_SWE_841840-3',
                                  
                        'TUR_World_841840-6', 'TUR_USA_841840-6', 'TUR_GBR_841840-6',
                        'TUR_FRA_841840-6', 'TUR_DEU_841840-6', 'TUR_SWE_841840-6',
                        
                        'TUR_World_841840-12', 'TUR_USA_841840-12', 'TUR_GBR_841840-12',
                        'TUR_FRA_841840-12', 'TUR_DEU_841840-12', 'TUR_SWE_841840-12',
                        
                             
                        
                       'Date']].merge(ITC_DF2[['Date', 
                                               'CHN_GBR_841840-1', 'DEU_GBR_841840-1', 'HUN_GBR_841840-1', 'NLD_GBR_841840-1',
                                               'CHN_GBR_841840-2', 'DEU_GBR_841840-2', 'HUN_GBR_841840-2', 'NLD_GBR_841840-2',
                                               'CHN_GBR_841840-3', 'DEU_GBR_841840-3', 'HUN_GBR_841840-3', 'NLD_GBR_841840-3',
                                               'CHN_GBR_841840-6', 'DEU_GBR_841840-6', 'HUN_GBR_841840-6', 'NLD_GBR_841840-6',
                                               'CHN_GBR_841840-12', 'DEU_GBR_841840-12', 'HUN_GBR_841840-12', 'NLD_GBR_841840-12'
                                               ]], 
#                        on = 'Date',how = 'left').merge(EPU_DF1[['Date', 
#                                                                 'EPU_CHN-1','EPU_CHN-2','EPU_CHN-3','EPU_CHN-6','EPU_CHN-12' ]],
                        on = 'Date',how = 'left').merge(EPU_DF2[['Date', 
                                                                 'EPU_UK-1','EPU_UK-2','EPU_UK-3','EPU_UK-6','EPU_UK-12' ]], 
                        on = 'Date',how = 'left').merge(EPU_World[['Date',
                                                                   'EPU_World-1','EPU_World-2','EPU_World-3','EPU_World-6','EPU_World-12']],
                        on = 'Date',how = 'left').merge(OECD_DF1[['Date',
                                                                  'BCI_TUR-1','CCI_TUR-1','CLI_TUR-1','GDP_TUR-1',
                                                                  'BCI_TUR-2','CCI_TUR-2','CLI_TUR-2','GDP_TUR-2',
                                                                  'BCI_TUR-3','CCI_TUR-3','CLI_TUR-3','GDP_TUR-3',
                                                                  'BCI_TUR-6','CCI_TUR-6','CLI_TUR-6','GDP_TUR-6',
                                                                  'BCI_TUR-12','CCI_TUR-12','CLI_TUR-12','GDP_TUR-12']], 
                                                                   
                        on = 'Date',how = 'left').merge(OECD_DF2[['Date',
                                                                  'BCI_GBR-1','CCI_GBR-1','CLI_GBR-1','GDP_GBR-1',
                                                                  'BCI_GBR-2','CCI_GBR-2','CLI_GBR-2','GDP_GBR-2',
                                                                  'BCI_GBR-3','CCI_GBR-3','CLI_GBR-3','GDP_GBR-3',
                                                                  'BCI_GBR-6','CCI_GBR-6','CLI_GBR-6','GDP_GBR-6',
                                                                  'BCI_GBR-12','CCI_GBR-12','CLI_GBR-12','GDP_GBR-12']], 
#                        on = 'Date',how = 'left').merge(OECD_DF3[['Date',
#                                                                  'PPI_CHN-1', 'PPI_GBR-1',
#                                                                  'PPI_CHN-2', 'PPI_GBR-2',
#                                                                  'PPI_CHN-3', 'PPI_GBR-3',
#                                                                  'PPI_CHN-6', 'PPI_GBR-6',
#                                                                  'PPI_CHN-12', 'PPI_GBR-12']], 
                        on = 'Date',how = 'left').merge(OECD_DF4[['Date',
                                                                  'CPI_TUR-1','CPI_GBR-1',
                                                                  'CPI_TUR-2','CPI_GBR-2',
                                                                  'CPI_TUR-3','CPI_GBR-3',
                                                                  'CPI_TUR-6','CPI_GBR-6',
                                                                 'CPI_TUR-12','CPI_GBR-12']], 
                        on = 'Date',how = 'left').merge(OECD_DF5[['Date',
                                                                  'TRY-1','GBP-1',
                                                                  'TRY-2','GBP-2',
                                                                  'TRY-3','GBP-3',
                                                                  'TRY-6','GBP-6',
                                                                  'TRY-12','GBP-12']], 
                        on = 'Date',how = 'left').merge(OTHER_DF1[['Date',
                                                                   'World-1','World-2','World-3','World-6','World-12']], 
                        on = 'Date',how = 'left')
#Data_Core_1236_12=Data_Core_1236_12.dropna()
print(Data_Core_1236_12.columns,Data_Core_1236_12.shape)
# Out:
# Index(['TUR_GBR_841840', 'TUR_World_841840-1', 'TUR_USA_841840-1',
#        'TUR_GBR_841840-1', 'TUR_FRA_841840-1', 'TUR_DEU_841840-1',
#        'TUR_SWE_841840-1', 'TUR_World_841840-2', 'TUR_USA_841840-2',
#        'TUR_GBR_841840-2',
#        ...
#        'GBP-3', 'TRY-6', 'GBP-6', 'TRY-12', 'GBP-12', 'World-1', 'World-2',
#        'World-3', 'World-6', 'World-12'],
#       dtype='object', length=127) (136, 127)

# %%
#PairPlot for TURKEYS Exports to GBR and Political Uncertainity
sns.pairplot(Data_Core_1[['TUR_GBR_841840',
       'EPU_UK-1', 'EPU_World-1']])

# %%
# Pairplots TURKEYS Exports to GBR and its top 5 markets

sns.pairplot(Data_Core_1[['TUR_GBR_841840','TUR_World_841840-1', 'TUR_USA_841840-1', 'TUR_GBR_841840-1',
       'TUR_FRA_841840-1', 'TUR_DEU_841840-1', 'TUR_SWE_841840-1']])

# %%
# Pairplots TURKEYS Exports to GBR and GBR top 4 exporters 
sns.pairplot(Data_Core_1[['TUR_GBR_841840','CHN_GBR_841840-1', 'DEU_GBR_841840-1', 'HUN_GBR_841840-1', 'NLD_GBR_841840-1']])

# %%
Data_Core_1236_12.to_excel('Out_841840_TUR_UK_Data_Core_1236_12.xlsx',index = False)
