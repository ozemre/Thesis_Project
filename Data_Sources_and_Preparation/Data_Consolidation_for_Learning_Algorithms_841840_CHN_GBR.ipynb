# %% [markdown]
# 841840 China to UK Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
import seaborn as sns
# %matplotlib inline

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
# Reading Excel Files

# %%
ITC_DF1 = pd.ExcelFile('ITC_Trade_Data\841840_China_all.xlsx')
ITC_DF1 = ITC_DF1.parse('Sheet1', header=0,index_col=None, na_values=['NA'])

# %%
ITC_DF1.columns
# Out:
# Index(['CHN_World_841840', 'CHN_USA_841840', 'CHN_GBR_841840',
#        'CHN_DEU_841840', 'CHN_FRA_841840', 'CHN_JPN_841840', 'Date',
#        'CHN_World_841840-1', 'CHN_World_841840-2', 'CHN_World_841840-3',
#        'CHN_World_841840-6', 'CHN_World_841840-12', 'CHN_USA_841840-1',
#        'CHN_USA_841840-2', 'CHN_USA_841840-3', 'CHN_USA_841840-6',
#        'CHN_USA_841840-12', 'CHN_JPN_841840-1', 'CHN_JPN_841840-2',
#        'CHN_JPN_841840-3', 'CHN_JPN_841840-6', 'CHN_JPN_841840-12',
#        'CHN_FRA_841840-1', 'CHN_FRA_841840-2', 'CHN_FRA_841840-3',
#        'CHN_FRA_841840-6', 'CHN_FRA_841840-12', 'CHN_GBR_841840-1',
#        'CHN_GBR_841840-2', 'CHN_GBR_841840-3', 'CHN_GBR_841840-6',
#        'CHN_GBR_841840-12', 'CHN_DEU_841840-1', 'CHN_DEU_841840-2',
#        'CHN_DEU_841840-3', 'CHN_DEU_841840-6', 'CHN_DEU_841840-12'],
#       dtype='object')

# %%
ITC_DF2 = pd.ExcelFile('ITC_Trade_Data\841840_UK_all.xlsx')
ITC_DF2 = ITC_DF2.parse('Sheet1', header=0,index_col=None, na_values=['NA'])
ITC_DF2.columns
# Out:
# Index(['TUR_GBR_841840', 'CHN_GBR_841840', 'DEU_GBR_841840', 'HUN_GBR_841840',
#        'NLD_GBR_841840', 'Date', 'TUR_GBR_841840-1', 'TUR_GBR_841840-2',
#        'TUR_GBR_841840-3', 'TUR_GBR_841840-6', 'TUR_GBR_841840-12',
#        'CHN_GBR_841840-1', 'CHN_GBR_841840-2', 'CHN_GBR_841840-3',
#        'CHN_GBR_841840-6', 'CHN_GBR_841840-12', 'DEU_GBR_841840-1',
#        'DEU_GBR_841840-2', 'DEU_GBR_841840-3', 'DEU_GBR_841840-6',
#        'DEU_GBR_841840-12', 'NLD_GBR_841840-1', 'NLD_GBR_841840-2',
#        'NLD_GBR_841840-3', 'NLD_GBR_841840-6', 'NLD_GBR_841840-12',
#        'HUN_GBR_841840-1', 'HUN_GBR_841840-2', 'HUN_GBR_841840-3',
#        'HUN_GBR_841840-6', 'HUN_GBR_841840-12'],
#       dtype='object')

# %%
EPU_DF1 = pd.ExcelFile('Economic_Uncertainty\EPU_CHN.xlsx')
EPU_DF1 = EPU_DF1.parse('Sheet1', header=0,index_col=None, na_values=['NA'])
EPU_DF1.columns
# Out:
# Index(['Date', 'EPU_CHN', 'EPU_CHN-1', 'EPU_CHN-2', 'EPU_CHN-3', 'EPU_CHN-6',
#        'EPU_CHN-12'],
#       dtype='object')

# %%
EPU_DF2 = pd.ExcelFile('Economic_Uncertainty\EPU_UK.xlsx')
EPU_DF2 = EPU_DF2.parse('Sheet1', header=0,index_col=None, na_values=['NA'])
EPU_DF2.columns
# Out:
# Index(['Date', 'EPU_UK', 'EPU_UK-1', 'EPU_UK-2', 'EPU_UK-3', 'EPU_UK-6',
#        'EPU_UK-12'],
#       dtype='object')

# %%
EPU_World = pd.ExcelFile('Economic_Uncertainty\EPU_World.xlsx')
EPU_World = EPU_World.parse('Sheet1', header=0,index_col=None, na_values=['NA'])
EPU_World.columns
# Out:
# Index(['Date', 'EPU_World', 'EPU_World-1', 'EPU_World-2', 'EPU_World-3',
#        'EPU_World-6', 'EPU_World-12'],
#       dtype='object')

# %%
# Reading Related CSV Files

# %%
OECD_DF1 = pd.read_csv('OECD\BCI_CCI_CLI_GDP_CHN.csv')
OECD_DF1.columns
# Out:
# Index(['Date', 'BCI_CHN', 'BCI_CHN-1', 'BCI_CHN-2', 'BCI_CHN-3', 'BCI_CHN-6',
#        'BCI_CHN-12', 'CCI_CHN', 'CCI_CHN-1', 'CCI_CHN-2', 'CCI_CHN-3',
#        'CCI_CHN-6', 'CCI_CHN-12', 'CLI_CHN', 'CLI_CHN-1', 'CLI_CHN-2',
#        'CLI_CHN-3', 'CLI_CHN-6', 'CLI_CHN-12', 'GDP_CHN', 'GDP_CHN-1',
#        'GDP_CHN-2', 'GDP_CHN-3', 'GDP_CHN-6', 'GDP_CHN-12'],
#       dtype='object')

# %%
OECD_DF2 = pd.read_csv('OECD\BCI_CCI_CLI_GDP_GBR.csv')
OECD_DF2.columns
# Out:
# Index(['Date', 'BCI_GBR', 'BCI_GBR-1', 'BCI_GBR-2', 'BCI_GBR-3', 'BCI_GBR-6',
#        'BCI_GBR-12', 'CCI_GBR', 'CCI_GBR-1', 'CCI_GBR-2', 'CCI_GBR-3',
#        'CCI_GBR-6', 'CCI_GBR-12', 'CLI_GBR', 'CLI_GBR-1', 'CLI_GBR-2',
#        'CLI_GBR-3', 'CLI_GBR-6', 'CLI_GBR-12', 'GDP_GBR', 'GDP_GBR-1',
#        'GDP_GBR-2', 'GDP_GBR-3', 'GDP_GBR-6', 'GDP_GBR-12'],
#       dtype='object')

# %%
#OECD_DF3 = pd.read_csv('OECD\PPI_CHN_UK.csv')
#OECD_DF3.columns

# %%
OECD_DF4 = pd.read_csv('OECD\CPI_CHN_UK.csv')
OECD_DF4.columns
# Out:
# Index(['Date', 'CPI_CHN', 'CPI_CHN-1', 'CPI_CHN-2', 'CPI_CHN-3', 'CPI_CHN-6',
#        'CPI_CHN-12', 'CPI_GBR', 'CPI_GBR-1', 'CPI_GBR-2', 'CPI_GBR-3',
#        'CPI_GBR-6', 'CPI_GBR-12'],
#       dtype='object')

# %%
OECD_DF5 = pd.read_csv('OECD\CNY_GBP.csv')
OECD_DF5.columns
# Out:
# Index(['Date', 'CNY', 'CNY-1', 'CNY-2', 'CNY-3', 'CNY-6', 'CNY-12', 'GBP',
#        'GBP-1', 'GBP-2', 'GBP-3', 'GBP-6', 'GBP-12'],
#       dtype='object')

# %%
OTHER_DF1 = pd.read_csv('Global_Trade\WorldTrade.csv')
OTHER_DF1.columns
# Out:
# Index(['Date', 'World', 'World-1', 'World-2', 'World-3', 'World-6',
#        'World-12'],
#       dtype='object')

# %%
# Data_Core for the current month
Data_Core = ITC_DF1[['CHN_World_841840', 'CHN_USA_841840', 'CHN_JPN_841840',
       'CHN_FRA_841840', 'CHN_GBR_841840', 'CHN_DEU_841840', 'Date']].merge(ITC_DF2[['Date','TUR_GBR_841840', 'DEU_GBR_841840', 'NLD_GBR_841840', 'HUN_GBR_841840' ]], 
                        on = 'Date',how = 'left').merge(EPU_DF1[['Date', 'EPU_CHN'      ]],
                        on = 'Date',how = 'left').merge(EPU_DF2[['Date', 'EPU_UK'      ]], 
                        on = 'Date',how = 'left').merge(EPU_World[['Date','EPU_World']],
                        on = 'Date',how = 'left').merge(OECD_DF1[['Date','BCI_CHN','CCI_CHN','CLI_CHN','GDP_CHN']], 
                        on = 'Date',how = 'left').merge(OECD_DF2[['Date','BCI_GBR','CCI_GBR','CLI_GBR','GDP_GBR']], 
#                        on = 'Date',how = 'left').merge(OECD_DF3[['Date','PPI_CHN', 'PPI_GBR']], 
                        on = 'Date',how = 'left').merge(OECD_DF4[['Date','CPI_CHN','CPI_GBR']], 
                        on = 'Date',how = 'left').merge(OECD_DF5[['Date','CNY','GBP']], 
                        on = 'Date',how = 'left').merge(OTHER_DF1[['Date','World']], 
                        on = 'Date',how = 'left')
#Data_Core=Data_Core.dropna()
print(Data_Core.columns,Data_Core.shape)
# Out:
# Index(['CHN_World_841840', 'CHN_USA_841840', 'CHN_JPN_841840',
#        'CHN_FRA_841840', 'CHN_GBR_841840', 'CHN_DEU_841840', 'Date',
#        'TUR_GBR_841840', 'DEU_GBR_841840', 'NLD_GBR_841840', 'HUN_GBR_841840',
#        'EPU_CHN', 'EPU_UK', 'EPU_World', 'BCI_CHN', 'CCI_CHN', 'CLI_CHN',
#        'GDP_CHN', 'BCI_GBR', 'CCI_GBR', 'CLI_GBR', 'GDP_GBR', 'CPI_CHN',
#        'CPI_GBR', 'CNY', 'GBP', 'World'],
#       dtype='object') (141, 27)

# %%
# Data_Core for Y current month and X for the previous month
Data_Core_1 = ITC_DF1[['CHN_World_841840-1', 'CHN_USA_841840-1', 'CHN_JPN_841840-1',
       'CHN_FRA_841840-1', 'CHN_GBR_841840', 'CHN_DEU_841840-1', 'CHN_GBR_841840-1',
                       
                       'Date']].merge(ITC_DF2[['Date', 'TUR_GBR_841840-1','DEU_GBR_841840-1', 'NLD_GBR_841840-1', 'HUN_GBR_841840-1' ]], 
                        on = 'Date',how = 'left').merge(EPU_DF1[['Date', 'EPU_CHN-1'      ]],
                        on = 'Date',how = 'left').merge(EPU_DF2[['Date', 'EPU_UK-1'      ]], 
                        on = 'Date',how = 'left').merge(EPU_World[['Date','EPU_World-1']],
                        on = 'Date',how = 'left').merge(OECD_DF1[['Date','BCI_CHN-1','CCI_CHN-1','CLI_CHN-1','GDP_CHN-1']], 
                        on = 'Date',how = 'left').merge(OECD_DF2[['Date','BCI_GBR-1','CCI_GBR-1','CLI_GBR-1','GDP_GBR-1']], 
 #                       on = 'Date',how = 'left').merge(OECD_DF3[['Date','PPI_CHN-1', 'PPI_GBR-1']], 
                        on = 'Date',how = 'left').merge(OECD_DF4[['Date','CPI_CHN-1','CPI_GBR-1']], 
                        on = 'Date',how = 'left').merge(OECD_DF5[['Date','CNY-1','GBP-1']], 
                        on = 'Date',how = 'left').merge(OTHER_DF1[['Date','World-1']], 
                        on = 'Date',how = 'left')
#Data_Core_1=Data_Core_1.dropna()
Data_Core_1=Data_Core_1.fillna(0)
print(Data_Core_1.columns,Data_Core_1.shape)
# Out:
# Index(['CHN_World_841840-1', 'CHN_USA_841840-1', 'CHN_JPN_841840-1',
#        'CHN_FRA_841840-1', 'CHN_GBR_841840', 'CHN_DEU_841840-1',
#        'CHN_GBR_841840-1', 'Date', 'TUR_GBR_841840-1', 'DEU_GBR_841840-1',
#        'NLD_GBR_841840-1', 'HUN_GBR_841840-1', 'EPU_CHN-1', 'EPU_UK-1',
#        'EPU_World-1', 'BCI_CHN-1', 'CCI_CHN-1', 'CLI_CHN-1', 'GDP_CHN-1',
#        'BCI_GBR-1', 'CCI_GBR-1', 'CLI_GBR-1', 'GDP_GBR-1', 'CPI_CHN-1',
#        'CPI_GBR-1', 'CNY-1', 'GBP-1', 'World-1'],
#       dtype='object') (141, 28)

# %%
# Data_Core for Y current month and X for the previous months (-1, -2, -3, -6 and -12 months)

Data_Core_1236_12 = ITC_DF1[['CHN_GBR_841840', 
                        'CHN_World_841840-1', 'CHN_USA_841840-1', 'CHN_JPN_841840-1',
                        'CHN_FRA_841840-1', 'CHN_DEU_841840-1', 'CHN_GBR_841840-1',
                       'CHN_World_841840-2', 'CHN_USA_841840-2', 'CHN_JPN_841840-2',
                        'CHN_FRA_841840-2', 'CHN_DEU_841840-2', 'CHN_GBR_841840-2',
                         'CHN_World_841840-3', 'CHN_USA_841840-3', 'CHN_JPN_841840-3',
                        'CHN_FRA_841840-3', 'CHN_DEU_841840-3', 'CHN_GBR_841840-3',
                         'CHN_World_841840-6', 'CHN_USA_841840-6', 'CHN_JPN_841840-6',
                        'CHN_FRA_841840-6', 'CHN_DEU_841840-6', 'CHN_GBR_841840-6',
                        'CHN_World_841840-12', 'CHN_USA_841840-12', 'CHN_JPN_841840-12',
                        'CHN_FRA_841840-12', 'CHN_DEU_841840-12', 'CHN_GBR_841840-12',
                       'Date']].merge(ITC_DF2[['Date', 
                                               'TUR_GBR_841840-1','DEU_GBR_841840-1', 'NLD_GBR_841840-1', 'HUN_GBR_841840-1',
                                               'TUR_GBR_841840-2','DEU_GBR_841840-2', 'NLD_GBR_841840-2', 'HUN_GBR_841840-2',
                                               'TUR_GBR_841840-3','DEU_GBR_841840-3', 'NLD_GBR_841840-3', 'HUN_GBR_841840-3',
                                               'TUR_GBR_841840-6','DEU_GBR_841840-6', 'NLD_GBR_841840-6', 'HUN_GBR_841840-6',
                                               'TUR_GBR_841840-12','DEU_GBR_841840-12', 'NLD_GBR_841840-12', 'HUN_GBR_841840-12']], 
                        on = 'Date',how = 'left').merge(EPU_DF1[['Date', 
                                                                 'EPU_CHN-1','EPU_CHN-2','EPU_CHN-3','EPU_CHN-6','EPU_CHN-12' ]],
                        on = 'Date',how = 'left').merge(EPU_DF2[['Date', 
                                                                 'EPU_UK-1','EPU_UK-2','EPU_UK-3','EPU_UK-6','EPU_UK-12' ]], 
                        on = 'Date',how = 'left').merge(EPU_World[['Date',
                                                                   'EPU_World-1','EPU_World-2','EPU_World-3','EPU_World-6','EPU_World-12']],
                        on = 'Date',how = 'left').merge(OECD_DF1[['Date',
                                                                  'BCI_CHN-1','CCI_CHN-1','CLI_CHN-1','GDP_CHN-1',
                                                                  'BCI_CHN-2','CCI_CHN-2','CLI_CHN-2','GDP_CHN-2',
                                                                  'BCI_CHN-3','CCI_CHN-3','CLI_CHN-3','GDP_CHN-3',
                                                                  'BCI_CHN-6','CCI_CHN-6','CLI_CHN-6','GDP_CHN-6',
                                                                 'BCI_CHN-12','CCI_CHN-12','CLI_CHN-12','GDP_CHN-12']], 
                        on = 'Date',how = 'left').merge(OECD_DF2[['Date',
                                                                  'BCI_GBR-1','CCI_GBR-1','CLI_GBR-1','GDP_GBR-1',
                                                                  'BCI_GBR-2','CCI_GBR-2','CLI_GBR-2','GDP_GBR-2',
                                                                  'BCI_GBR-3','CCI_GBR-3','CLI_GBR-3','GDP_GBR-3',
                                                                  'BCI_GBR-6','CCI_GBR-6','CLI_GBR-6','GDP_GBR-6',
                                                                  'BCI_GBR-12','CCI_GBR-12','CLI_GBR-12','GDP_GBR-12']], 
#                        on = 'Date',how = 'left').merge(OECD_DF3[['Date',
#                                                                  'PPI_CHN-1', 'PPI_GBR-1',
#                                                                  'PPI_CHN-2', 'PPI_GBR-2',
#                                                                  'PPI_CHN-3', 'PPI_GBR-3',
#                                                                  'PPI_CHN-6', 'PPI_GBR-6',
#                                                                  'PPI_CHN-12', 'PPI_GBR-12']], 
                        on = 'Date',how = 'left').merge(OECD_DF4[['Date',
                                                                  'CPI_CHN-1','CPI_GBR-1',
                                                                  'CPI_CHN-2','CPI_GBR-2',
                                                                  'CPI_CHN-3','CPI_GBR-3',
                                                                  'CPI_CHN-6','CPI_GBR-6',
                                                                 'CPI_CHN-12','CPI_GBR-12']], 
                        on = 'Date',how = 'left').merge(OECD_DF5[['Date',
                                                                  'CNY-1','GBP-1',
                                                                  'CNY-2','GBP-2',
                                                                  'CNY-3','GBP-3',
                                                                  'CNY-6','GBP-6',
                                                                  'CNY-12','GBP-12']], 
                        on = 'Date',how = 'left').merge(OTHER_DF1[['Date',
                                                                   'World-1','World-2','World-3','World-6','World-12']], 
                        on = 'Date',how = 'left')
#Data_Core_1236_12=Data_Core_1236_12.dropna()
print(Data_Core_1236_12.columns,Data_Core_1236_12.shape)
# Out:
# Index(['CHN_GBR_841840', 'CHN_World_841840-1', 'CHN_USA_841840-1',
#        'CHN_JPN_841840-1', 'CHN_FRA_841840-1', 'CHN_DEU_841840-1',
#        'CHN_GBR_841840-1', 'CHN_World_841840-2', 'CHN_USA_841840-2',
#        'CHN_JPN_841840-2',
#        ...
#        'GBP-3', 'CNY-6', 'GBP-6', 'CNY-12', 'GBP-12', 'World-1', 'World-2',
#        'World-3', 'World-6', 'World-12'],
#       dtype='object', length=132) (141, 132)

# %%
#PairPlot for CHINA Exports to GBR and Political Uncertainity
sns.pairplot(Data_Core_1[['CHN_GBR_841840','EPU_CHN-1',
       'EPU_UK-1', 'EPU_World-1']])

# %%
# Pairplots CHINA Exports to GBR and its top 5 markets
sns.pairplot(Data_Core_1[['CHN_GBR_841840','CHN_World_841840-1', 'CHN_USA_841840-1', 'CHN_JPN_841840-1',
       'CHN_FRA_841840-1', 'CHN_DEU_841840-1']])

# %%
# Pairplots CHINA Exports to GBR and GBR top 4 exporters 
sns.pairplot(Data_Core_1[['CHN_GBR_841840','DEU_GBR_841840-1', 'NLD_GBR_841840-1', 'HUN_GBR_841840-1']])

# %%
Data_Core_1236_12.to_excel('Out_841840_CHN_UK_Data_Core_1236_12.xlsx',index = False)
